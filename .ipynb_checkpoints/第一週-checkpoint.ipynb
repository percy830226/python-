# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 第一題：畫出想要的形狀

# %%
#設定各點 x,y 座標
list_x = [1, 2, 3, 4, 5]
list_y = [1, 4, 1, 4, 1]

# %%
plt.plot(list_x, list_y, marker='.', ms=20)

# %% [markdown]
# ### 第二題：臺北市最高最低溫分佈圖

# %%
list_x = ['Jan','Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'] #月份
list_hightmp = [19.1, 19.6, 22.1, 25.7, 29.2, 32.0, 34.3, 33.8, 31.1, 27.5, 24.2, 20.7] #高溫
list_lowtmp = [13.9, 14.2, 15.8, 19.0, 22.3, 24.6, 26.3, 26.1, 24.8, 22.3, 19.3, 15.6] #低溫

# %%
plt.plot(list_x, list_hightmp, color="red", marker='.', ms=10)
plt.plot(list_x, list_lowtmp, color="blue", marker='.', ms=10)

# %% [markdown]
# ### 挑戰題一：買相機

# %%
list_month = [ 'Sep', 'Oct', 'Nov', 'Dec']
list_price = [10000, 150000, 230000, 80000]
list_total =[]
price_sum = 0

# %%
for i in list_price: #以 for 迴圈方式進行累加
    price_sum += i
    list_total.append(price_sum)

# %%
plt.plot(list_month, list_total, color="red", marker='.', ms=10)

# %%
plt.pie(list_price,  labels = list_month, labeldistance = 1.1, autopct = "%3.2f%%", shadow =True, startangle = 90, pctdistance = 0.6)
# Out:
# ([<matplotlib.patches.Wedge at 0x217596d5e80>,
# ...
#  [Text(-0.0734718947966144, 1.0975435666409765, 'Sep'),
#   Text(-0.9977999911567856, 0.4630282687347702, 'Oct'),
#   Text(0.5605782575958832, -0.946441766360067, 'Nov'),
#   Text(0.5605783683612221, 0.9464417007536545, 'Dec')],
#  [Text(-0.04007557897997148, 0.5986601272587143, '2.13%'),
#   Text(-0.5442545406309739, 0.25256087385532916, '31.91%'),
#   Text(0.3057699586886635, -0.5162409634691274, '48.94%'),
#   Text(0.3057700191061211, 0.5162409276838115, '17.02%')])
